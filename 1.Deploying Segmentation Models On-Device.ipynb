# %% [markdown]
# <p style="background-color:#fff6e4; padding:15px; border-width:3px; border-color:#f5ecda; border-style:solid; border-radius:6px"> ⏳ <b>Note <code>(Kernel Starting)</code>:</b> This notebook takes about 30 seconds to be ready to use. You may start and watch the video while you wait.</p>

# %%
# !pip install qai_hub_models

# import pkg_resources
# installed_packages = pkg_resources.working_set
# for package in installed_packages:
#     if 'qai_hub_models' in package.key:
#         print(f"{package.key}=={package.version}")

# %%
import qai_hub_models

# %% [markdown]
# ![image.png](attachment:80432f31-d768-4f58-b37f-9370675e5687.png)

# %% [markdown]
# [FFNet Paper](https://arxiv.org/abs/2206.08236)

# %%
from qai_hub_models.models.ffnet_40s import Model

# %%
from torchinfo import summary

# %%
# Load from pre-trained weights
model = Model.from_pretrained()
input_shape = (1, 3, 1024, 2048)
stats = summary(model, 
  input_size=input_shape, 
  col_names=["num_params", "mult_adds"]
)
print(stats)
# Out:
# Downloading data at https://github.com/quic/aimet-model-zoo/releases/download/torch_segmentation_ffnet/ffnet40S_dBBB_cityscapes_state_dict_quarts.pth to C:\Users\CGDC\.qaihm\models\ffnet\v1\ffnet40S\ffnet40S_dBBB_cityscapes_state_dict_quarts.pth...
# 100%|███████████████████████████████████████████████████████████████████████████████████████████| 55.8M/55.8M [00:09<00:00, 5.67MB/s]
# Done
# cityscapes_segmentation requires repository https://github.com/Qualcomm-AI-research/FFNet.git . Ok to clone? [Y/n]
#  y
# Cloning https://github.com/Qualcomm-AI-research/FFNet.git to C:\Users\CGDC\.qaihm\models\cityscapes_segmentation\v2\Qualcomm-AI-research_FFNet_git...
# Done
# Loading pretrained model state dict from C:\Users\CGDC\.qaihm\models\ffnet\v1\ffnet40S/ffnet40S_dBBB_cityscapes_state_dict_quarts.pth
# Initializing ffnnet40S_dBBB_mobile weights
# ==============================================================================================================
# Layer (type:depth-idx)                                       Param #                   Mult-Adds
# ==============================================================================================================
# FFNet40S                                                     --                        --
# ├─FFNet: 1-1                                                 --                        --
# │    └─ResNetS: 2-1                                          --                        --
# │    │    └─Conv2d: 3-1                                      864                       452,984,832
# │    │    └─BatchNorm2d: 3-2                                 64                        64
# │    │    └─ReLU: 3-3                                        --                        --
# │    │    └─Conv2d: 3-4                                      18,432                    2,415,919,104
# │    │    └─BatchNorm2d: 3-5                                 128                       128
# │    │    └─ReLU: 3-6                                        --                        --
# │    │    └─Sequential: 3-7                                  300,160                   9,797,895,296
# │    │    └─Sequential: 3-8                                  1,411,840                 11,542,727,424
# │    │    └─Sequential: 3-9                                  3,900,288                 7,977,571,200
# │    │    └─Sequential: 3-10                                 7,071,360                 3,617,592,960
# │    └─FFNetUpHead: 2-2                                      --                        --
# │    │    └─Sequential: 3-11                                 1,208,147                 26,571,541,312
# ==============================================================================================================
# Total params: 13,911,283
# Trainable params: 13,911,283
# Non-trainable params: 0
# Total mult-adds (G): 62.38
# ==============================================================================================================
# Input size (MB): 25.17
# Forward/backward pass size (MB): 1269.30
# Params size (MB): 55.65
# Estimated Total Size (MB): 1350.11
# ==============================================================================================================

# %% [markdown]
# ## Exercise: Try another variant of FFNet

# %%
# High resolution variants
from qai_hub_models.models.ffnet_40s import Model
#from qai_hub_models.models.ffnet_54s import Model
#from qai_hub_models.models.ffnet_78s import Model

# Low resolution variants
low_res_input_shape = (1, 3, 512, 1024)
#from qai_hub_models.models.ffnet_78s_lowres import Model
#from qai_hub_models.models.ffnet_122ns_lowres import Model

model = Model.from_pretrained()
stats = summary(model, 
  input_size=input_shape, # use low_res_input_shape for low_res models
  col_names=["num_params", "mult_adds"]
)
print(stats)
# Out:
# Loading pretrained model state dict from C:\Users\CGDC\.qaihm\models\ffnet\v1\ffnet40S/ffnet40S_dBBB_cityscapes_state_dict_quarts.pth
# Initializing ffnnet40S_dBBB_mobile weights
# ==============================================================================================================
# Layer (type:depth-idx)                                       Param #                   Mult-Adds
# ==============================================================================================================
# FFNet40S                                                     --                        --
# ├─FFNet: 1-1                                                 --                        --
# │    └─ResNetS: 2-1                                          --                        --
# │    │    └─Conv2d: 3-1                                      864                       452,984,832
# │    │    └─BatchNorm2d: 3-2                                 64                        64
# │    │    └─ReLU: 3-3                                        --                        --
# │    │    └─Conv2d: 3-4                                      18,432                    2,415,919,104
# │    │    └─BatchNorm2d: 3-5                                 128                       128
# │    │    └─ReLU: 3-6                                        --                        --
# │    │    └─Sequential: 3-7                                  300,160                   9,797,895,296
# │    │    └─Sequential: 3-8                                  1,411,840                 11,542,727,424
# │    │    └─Sequential: 3-9                                  3,900,288                 7,977,571,200
# │    │    └─Sequential: 3-10                                 7,071,360                 3,617,592,960
# │    └─FFNetUpHead: 2-2                                      --                        --
# │    │    └─Sequential: 3-11                                 1,208,147                 26,571,541,312
# ==============================================================================================================
# Total params: 13,911,283
# Trainable params: 13,911,283
# Non-trainable params: 0
# Total mult-adds (G): 62.38
# ==============================================================================================================
# Input size (MB): 25.17
# Forward/backward pass size (MB): 1269.30
# Params size (MB): 55.65
# Estimated Total Size (MB): 1350.11
# ==============================================================================================================

# %% [markdown]
# ## Setup AI Hub for device-in-the-loop deployment

# %%
import qai_hub

# %% [markdown]
# <p style="background-color:#fff6ff; padding:15px; border-width:3px; border-color:#efe6ef; border-style:solid; border-radius:6px"> 💻 &nbsp; <b>Access Utils File and Helper Functions:</b> To access the files for this notebook, 1) click on the <em>"File"</em> option on the top menu of the notebook and then 2) click on <em>"Open"</em>. For more help, please see the <em>"Appendix - Tips and Help"</em> Lesson.</p>

# %%
# !pip install python-dotenv

# %%
import os
from dotenv import load_dotenv

load_dotenv()
# Out:
# True

# %%
from utils import get_ai_hub_api_token
ai_hub_api_token = get_ai_hub_api_token()

# !qai-hub configure --api_token $ai_hub_api_token
# Out:
# qai-hub configuration saved to C:\Users\CGDC/.qai_hub/client.ini
# ==================== C:\Users\CGDC/.qai_hub/client.ini ====================
# [api]
# api_token = sk-proj-7tXWoN8nhyoRIutGfzA6T3BlbkFJ3Q1WX3SDsD6hqx0maieI
# api_url = https://app.aihub.qualcomm.com
# web_url = https://app.aihub.qualcomm.com
# verbose = True
# C:\Users\CGDC\anaconda3\envs\myenv\lib\site-packages\qai_hub\_cli.py:272: UserWarning: Overwriting configuration: C:\Users\CGDC/.qai_hub/client.ini (previous configuration saved to C:\Users\CGDC/.qai_hub/client.ini.bak)
#   warnings.warn(

# %%
# %run -m qai_hub_models.models.ffnet_40s.demo
# Out:
# ---------------------------------------------------------------------------
# UserError                                 Traceback (most recent call last)
# File ~\anaconda3\envs\myenv\lib\runpy.py:224, in run_module(mod_name, init_globals, run_name, alter_sys)
#     222     run_name = mod_name
#     223 if alter_sys:
# --> 224     return _run_module_code(code, init_globals, run_name, mod_spec)
#     225 else:
#     226     # Leave the sys module alone
#     227     return _run_code(code, {}, init_globals, run_name, mod_spec)
#
# File ~\anaconda3\envs\myenv\lib\runpy.py:96, in _run_module_code(code, init_globals, mod_name, mod_spec, pkg_name, script_name)
#      94 with _TempModule(mod_name) as temp_module, _ModifiedArgv0(fname):
#      95     mod_globals = temp_module.module.__dict__
# ---> 96     _run_code(code, mod_globals, init_globals,
#      97               mod_name, mod_spec, pkg_name, script_name)
#      98 # Copy the globals of the temporary module, as they
#      99 # may be cleared when the temporary module goes away
#     100 return mod_globals.copy()
#
# File ~\anaconda3\envs\myenv\lib\runpy.py:86, in _run_code(code, run_globals, init_globals, mod_name, mod_spec, pkg_name, script_name)
#      78         pkg_name = mod_spec.parent
#      79 run_globals.update(__name__ = mod_name,
#      80                    __file__ = fname,
#      81                    __cached__ = cached,
#    (...)
#      84                    __package__ = pkg_name,
#      85                    __spec__ = mod_spec)
# ---> 86 exec(code, run_globals)
#      87 return run_globals
#
# File ~\anaconda3\envs\myenv\lib\site-packages\qai_hub_models\models\ffnet_40s\demo.py:16
#      12     cityscapes_segmentation_demo(FFNet40S, MODEL_ID, is_test=is_test)
#      15 if __name__ == "__main__":
# ---> 16     main()
#
# File ~\anaconda3\envs\myenv\lib\site-packages\qai_hub_models\models\ffnet_40s\demo.py:12, in main(is_test)
#      11 def main(is_test: bool = False):
# ---> 12     cityscapes_segmentation_demo(FFNet40S, MODEL_ID, is_test=is_test)
#
# File ~\anaconda3\envs\myenv\lib\site-packages\qai_hub_models\models\_shared\cityscapes_segmentation\demo.py:43, in cityscapes_segmentation_demo(model_type, model_id, is_test)
#      36 def cityscapes_segmentation_demo(
#      37     model_type: Type[CityscapesSegmentor],
#      38     model_id: str,
#      39     is_test: bool = False,
#      40 ):
#      41     # Demo parameters
#      42     parser = get_model_cli_parser(model_type)
# ---> 43     parser = get_on_device_demo_parser(
#      44         parser, available_target_runtimes=[TargetRuntime.TFLITE], add_output_dir=True
#      45     )
#      46     parser.add_argument(
#      47         "--image",
#      48         type=str,
#      49         help="File path or URL to an input image to use for the demo.",
#      50     )
#      51     args = parser.parse_args([] if is_test else None)
#
# File ~\anaconda3\envs\myenv\lib\site-packages\qai_hub_models\utils\args.py:122, in get_on_device_demo_parser(parser, available_target_runtimes, add_output_dir, default_device)
#     104 parser.add_argument(
#     105     "--hub-model-id",
#     106     type=str,
#    (...)
#     110     " Run export.py to get on-device demo command with models exported for you.",
#     111 )
#     112 parser.add_argument(
#     113     "--device",
#     114     type=str,
#     115     default=default_device,
#     116     help="If running on-device, use this device.",
#     117 )
#     118 parser.add_argument(
#     119     "--chipset",
#     120     type=str,
#     121     default=None,
# --> 122     choices=sorted(get_qcom_chipsets(), reverse=True),
#     123     help="If set, will choose a random device with this chipset. "
#     124     "Overrides whatever is set in --device.",
#     125 )
#     126 parser.add_argument(
#     127     "--device-os",
#     128     type=str,
#     129     default="",
#     130     help="Optionally specified together with --device",
#     131 )
#     132 if add_output_dir:
#
# File ~\anaconda3\envs\myenv\lib\site-packages\qai_hub_models\utils\args.py:379, in get_qcom_chipsets()
#     375 def get_qcom_chipsets() -> Set[str]:
#     376     return set(
#     377         [
#     378             attr[len("chipset:") :]
# --> 379             for dev in hub.get_devices()
#     380             for attr in dev.attributes
#     381             if attr.startswith("chipset:qualcomm")
#     382         ]
#     383     )
#
# File ~\anaconda3\envs\myenv\lib\site-packages\qai_hub\client.py:2272, in Client.get_devices(self, name, os, attributes)
#    2229 def get_devices(
#    2230     self, name: str = "", os: str = "", attributes: str | List[str] = []
#    2231 ) -> List[Device]:
#    2232     """
#    2233     Returns a list of available devices.
#    2234
#    (...)
#    2270         devices = hub.get_devices(name="Samsung Galaxy S23")
#    2271     """
# -> 2272     return self._get_devices(name, os, attributes)
#
# File ~\anaconda3\envs\myenv\lib\site-packages\qai_hub\client.py:2220, in Client._get_devices(self, name, os, attributes, select)
#    2218 _validate_device_params(name, os, attributes)
#    2219 _validate_interval(os)
# -> 2220 devices_pb = _api_call(
#    2221     api.get_device_list, self.config, name, os, attributes, select=select
#    2222 )
#    2223 devices = []
#    2224 for dev in devices_pb.devices:
#
# File ~\anaconda3\envs\myenv\lib\site-packages\qai_hub\client.py:534, in _api_call(api_func, *args, **kwargs)
#     527 elif e.status_code == api_status_codes.HTTP_401_UNAUTHORIZED:
#     528     long_message = _visible_textbox(
#     529         "Failure to authenticate is likely caused by a bad or outdated API "
#     530         f"token in your {config_path} file. Please go to your Account page "
#     531         "to view your current token."
#     532     )
# --> 534     raise UserError(f"Failed to authenticate.\n{long_message}") from None
#     535 elif e.status_code == api_status_codes.HTTP_403_FORBIDDEN:
#     536     raise UserError(__get_exception_string(e)) from None
#
# UserError: Failed to authenticate.
#
# ┌────────────────────────────────────────────────────────────────────┐
# | Failure to authenticate is likely caused by a bad or outdated API  |
# | token in your ~/.qai_hub/client.ini file. Please go to your        |
# | Account page to view your current token.                           |
# └────────────────────────────────────────────────────────────────────┘

# %% [markdown]
# ## Run on a real smart phone!

# %% [markdown]
# <p style="background-color:#fff6e4; padding:15px; border-width:3px; border-color:#f5ecda; border-style:solid; border-radius:6px"> ⏳ <b>Note:</b> To spread the load across various devices, we are selecting a random device. Feel free to change it to any other device you prefer.</p>

# %%
devices = [
    "Samsung Galaxy S22 Ultra 5G",
    "Samsung Galaxy S22 5G",
    "Samsung Galaxy S22+ 5G",
    "Samsung Galaxy Tab S8",
    "Xiaomi 12",
    "Xiaomi 12 Pro",
    "Samsung Galaxy S22 5G",
    "Samsung Galaxy S23",
    "Samsung Galaxy S23+",
    "Samsung Galaxy S23 Ultra",
    "Samsung Galaxy S24",
    "Samsung Galaxy S24 Ultra",
    "Samsung Galaxy S24+",
]

import random
selected_device = random.choice(devices)
print(selected_device)

# %%
# %run -m qai_hub_models.models.ffnet_40s.export -- --device "$selected_device"

# %% [markdown]
# <p style="background-color:#fff1d7; padding:15px; "> <b>Note</b>: To view the URL for each job, you require login. You can experience sample results in the following urls.</p>
#
# * [FFNet 40s](https://aihub.qualcomm.com/mobile/models/ffnet_40s)
# * [FFNet 54s](https://aihub.qualcomm.com/mobile/models/ffnet_54s)
# * [FFNet 78s](https://aihub.qualcomm.com/mobile/models/ffnet_78s)
# * [FFNet 78s-low-res](https://aihub.qualcomm.com/mobile/models/ffnet_78s_lowres)
# * [FFNet 122ns-low-res](https://aihub.qualcomm.com/mobile/models/ffnet_122ns_lowres)

# %% [markdown]
# ## On Device Demo

# %%
# %run -m qai_hub_models.models.ffnet_40s.demo -- --device "$selected_device" --on-device
